# %% [markdown]
# # Grafico cleveland.
#
# Notebook para ajustar columnas, titulos y salida.

# %%
from pathlib import Path
import sys as Sistema

Ruta_Codigo = Path("..") / "Codigo"
Ruta_Graficos = Ruta_Codigo / "Graficos"
Sistema.path.append(str(Ruta_Graficos))

from Cleveland_Por_Categoria import (
    Generar_Paneles_Cleveland_Por_Items,
)

Nombre_Base = "Ballotage"

Items_A_Graficar = [7,25,29]

# Carpeta de salida para los SVG (ruta absoluta).
Carpeta_Salida = Path(__file__).parent / "Cleveland" if "__file__" in dir() \
    else Path(r"c:\Users\Patricio\Desktop\Paper\Graficos\Cleveland")

Generar_Paneles_Cleveland_Por_Items(
    Nombre_Base,
    Items = Items_A_Graficar,
    Columnas_Panel = 4,
    Titulo_General = "A) Opinion Change (Significant Items for "
                     "Ballotage Election)",
    Usar_Post_Hoc = True,
    Solo_Significativas = True,
    Mostrar_Grafico = True,
    Guardar_Archivo = True,
    Nombre_Archivo = "Cleveland_Ballotage.svg",
    Carpeta_Salida = Carpeta_Salida,
)
# Out:
# (<Figure size 4400x1400 with 9 Axes>,
#  [<Axes: title={'left': 'Item 7 (Conservative)'}, xlabel='Opinion Change Media'>,
#   <Axes: title={'left': 'Item 8 (Conservative)'}, xlabel='Opinion Change Media'>,
#   <Axes: title={'left': 'Item 9 (Progressive)'}, xlabel='Opinion Change Media'>,
#   <Axes: title={'left': 'Item 10 (Conservative)'}, xlabel='Opinion Change Media'>,
#   <Axes: title={'left': 'Item 24 (Progressive)'}, xlabel='Opinion Change Media'>,
#   <Axes: title={'left': 'Item 25 (Progressive)'}, xlabel='Opinion Change Media'>,
#   <Axes: title={'left': 'Item 30 (Conservative)'}, xlabel='Opinion Change Media'>,
#   <Axes: >])
